# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/IMDb_Dataset.csv')

# %%
df.head(10)
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
# 5                                  Jurassic Park          8.2  1993
# 6                              The Fifth Element          7.6  1997
# 7                                     Inside Out          8.1  2015
# 8                   Descendants: The Rise of Red          7.1  2024
# 9                                           Wish          5.6  2023
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# ...

# %%
df.tail(10)
# Out:
#                        Title  IMDb Rating  Year Certificates      Genre  \
# 390             Emilia Perez          7.2  2024            R     Comedy
# 391           Anyone But You          6.1  2023            R     Comedy
# 392     Deadpool & Wolverine          7.1  2024            R     Action
# 393       The Garfield Movie          5.9  2024           PG  Animation
# 394        Kinds of Kindness          7.0  2024            R     Comedy
# 395      Mother of the Bride          4.8  2024        TV-PG     Comedy
# 396  Beetlejuice Beetlejuice          7.1  2024            R     Comedy
# 397          The Idea of You          6.4  2024            R     Comedy
# 398                       IF          6.7  2024           PG  Animation
# 399             The Fall Guy          7.1  2024        PG-13     Action
#
#               Director                                       Star Cast  \
# 390    Jacques Audiard  Jacques AudiardThomas BidegainNicolas Livecchi
# ...

# %%
df.isnull()
# Out:
#      Title  IMDb Rating   Year  Certificates  Genre  Director  Star Cast  \
# 0    False        False  False         False  False     False      False
# 1    False        False  False         False  False     False      False
# 2    False        False  False         False  False     False      False
# 3    False        False  False         False  False     False      False
# 4    False        False  False         False  False     False      False
# ..     ...          ...    ...           ...    ...       ...        ...
# 395  False        False  False         False  False     False      False
# 396  False        False  False         False  False     False      False
# 397  False        False  False         False  False     False      False
# 398  False        False  False         False  False     False      False
# 399  False        False  False         False  False     False      False
#
#      MetaScore  Duration (minutes)
# 0        False               False
# ...

# %%
# isolating to or more rows []
df[df.index.isin(range(1,15))]
# Out:
#                                             Title  IMDb Rating  Year  \
# 1   Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2            Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                            Inglourious Basterds          8.4  2009
# 4                                     Borderlands          7.1  2024
# 5                                   Jurassic Park          8.2  1993
# 6                               The Fifth Element          7.6  1997
# 7                                      Inside Out          8.1  2015
# 8                    Descendants: The Rise of Red          7.1  2024
# 9                                            Wish          5.6  2023
# 10                               The Hunger Games          7.2  2012
# 11         Rebel Moon - Part One: A Child of Fire          5.6  2023
# 12          Harry Potter and the Sorcerer's Stone          7.6  2001
# 13                                          Wonka          7.0  2023
# ...

# %%
df.loc[50]
# Out:
# Title                                               WALL·E
# IMDb Rating                                            8.4
# Year                                                  2008
# Certificates                                             G
# Genre                                            Animation
# Director                                    Andrew Stanton
# Star Cast             Andrew StantonPete DocterJim Reardon
# MetaScore                                             95.0
# Duration (minutes)                                    98.0
# Name: 50, dtype: object

# %%
df.iloc[20:40]
# Out:
#                                                 Title  IMDb Rating  Year  \
# 20                                    Kung Fu Panda 4          6.3  2024
# 21                         Mad Max Beyond Thunderdome          6.2  1985
# 22                                     Manjummel Boys          8.4  2024
# 23                                       Golden Kamuy          6.4  2024
# 24                                       Interstellar          8.7  2014
# 25                                 Planet of the Apes          8.0  1968
# 26                                             Barbie          6.8  2023
# 27                                           Twisters          7.1  2024
# 28  The Hunger Games: The Ballad of Songbirds & Sn...          6.7  2023
# 29                                       Inside Out 2          7.1  2024
# 30                              Bad Boys: Ride or Die          7.1  2024
# 31                        Mad Max 2: The Road Warrior          7.6  1981
# ...

# %% [markdown]
#  Data visualzation
#
#  matplotlib and seaborn

# %%
df.plot.pie(y='Genre', figsize=(5,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-388eaab144eb> in <cell line: 1>()
# ----> 1 df.plot.pie(y='Genre',)
#
# NameError: name 'df' is not defined

# %%
# boxplot seaborn
sns.barplot(data=df,x='IMDb Rating', y='MetaScore').set(title='IMDb Rating vs MetaScore')
# Out:
# [Text(0.5, 1.0, 'IMDb Rating vs MetaScore')]

# %%
# barplot seaborn
sns.barplot(x='MetaScore', y = 'Genre', data=df)
# Out:
# <Axes: xlabel='MetaScore', ylabel='Genre'>

# %%
#matplotlib hstograms plot
y =  ['IMDb Rating', 'MetaScore', 'Duration']
plt.hist(y)
plt.show()

# %%
# Boxplot seaborn
sns.boxplot(data=df, x='Genre',y='Certificates')
# Out:
# <Axes: xlabel='Genre', ylabel='Certificates'>

# %%
#lineplot seaborn
sns.lineplot(data=df,x='Director',y='Genre')
# Out:
# <Axes: xlabel='Director', ylabel='Genre'>

# %%
df.columns
# Out:
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Duration (minutes)'],
#       dtype='object')

# %%
#violiinplot seaborn
import seaborn
seaborn.violinplot(x ='Certificates', y ='Year', data = df)
# Out:
# <Axes: xlabel='Certificates', ylabel='Year'>

# %%
#stripplot seaborn
seaborn.stripplot(x="Title", y="Certificates", data=df)
# Out:
# <Axes: xlabel='Title', ylabel='Certificates'>

# %%
# histplot seaborn
sns.histplot(data = df, x = "MetaScore", kde = True)
# Out:
# <Axes: xlabel='MetaScore', ylabel='Count'>

# %%
#pairplot seaborn
seaborn.pairplot(df, hue ='Genre')

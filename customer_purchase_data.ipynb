# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/customer_purchase_data.csv')

# %%
#top 5 rows
data.head()

# %%
#Bottom 5 rows
data.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# Data summary statistics all numeric columns
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data.isna()
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# Finding Null values
data.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
# isolating to or more rows []
data[data.index.isin(range(1,20))]
# Out:
#     Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 1    20       1   23579.773583                  4                2
# 2    27       1  127821.306432                 11                2
# 3    24       1  137798.623120                 19                3
# 4    31       1   99300.964220                 19                1
# 5    66       1   37758.117475                 14                4
# 6    39       1  126883.385286                 16                3
# 7    64       1   39707.359724                 13                2
# 8    43       0  102797.301269                 20                1
# 9    20       1   63854.921080                 16                0
# 10   66       1   66199.993929                 11                1
# 11   70       1   83556.718133                 11                2
# 12   54       0  114467.228969                  9                2
# 13   64       1   31880.893223                 17                0
# ...

# %%
data.loc[1499]
# Out:
# Age                      50.000000
# Gender                    0.000000
# AnnualIncome          52625.665974
# NumberOfPurchases        13.000000
# ProductCategory           0.000000
# TimeSpentOnWebsite       25.348017
# LoyaltyProgram            1.000000
# DiscountsAvailed          4.000000
# PurchaseStatus            1.000000
# Name: 1499, dtype: float64

# %%
data.iloc[2:20]
# Out:
#     Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 2    27       1  127821.306432                 11                2
# 3    24       1  137798.623120                 19                3
# 4    31       1   99300.964220                 19                1
# 5    66       1   37758.117475                 14                4
# 6    39       1  126883.385286                 16                3
# 7    64       1   39707.359724                 13                2
# 8    43       0  102797.301269                 20                1
# 9    20       1   63854.921080                 16                0
# 10   66       1   66199.993929                 11                1
# 11   70       1   83556.718133                 11                2
# 12   54       0  114467.228969                  9                2
# 13   64       1   31880.893223                 17                0
# 14   19       1  107485.660911                  7                1
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %% [markdown]
# Data visualzation
# matplotlib and seaborn

# %%
# Data visualzation
# matplotlib and seaborn

# %%
data.head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1

# %%
sns.barplot(data=data,x='ProductCategory', y='PurchaseStatus')
# Out:
# <Axes: xlabel='ProductCategory', ylabel='PurchaseStatus'>

# %%
sns.lineplot(data=data,x='Age',y='NumberOfPurchases')
# Out:
# <Axes: xlabel='Age', ylabel='NumberOfPurchases'>

# %%
#matplotlib hstograms plot
y =  ['Age',	'Gender',	'AnnualIncome',	'ProductCategory', 'PurchaseStatus']
plt.hist(y)
plt.show()

# %%
sns.boxplot(data=data,x='Age',y='NumberOfPurchases')
# Out:
# <Axes: xlabel='Age', ylabel='NumberOfPurchases'>

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
#violiinplot seaborn
import seaborn
seaborn.violinplot(x ='Gender', y ='DiscountsAvailed', data = data)
# Out:
# <Axes: xlabel='Gender', ylabel='DiscountsAvailed'>

# %%
#stripplot seaborn
seaborn.stripplot(x="ProductCategory", y="DiscountsAvailed", data=data)
# Out:
# <Axes: xlabel='ProductCategory', ylabel='DiscountsAvailed'>

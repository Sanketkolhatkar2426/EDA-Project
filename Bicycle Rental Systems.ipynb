# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/day.csv')

# %%
# Top 5 Rows
data.head(10)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
# 5        6  2011-01-06       1   0     1        0        4           1
# 6        7  2011-01-07       1   0     1        0        5           1
# 7        8  2011-01-08       1   0     1        0        6           0
# 8        9  2011-01-09       1   0     1        0        0           0
# 9       10  2011-01-10       1   0     1        0        1           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# ...

# %%
data.tail(10)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 721      722  2012-12-22       1   1    12        0        6           0
# 722      723  2012-12-23       1   1    12        0        0           0
# 723      724  2012-12-24       1   1    12        0        1           1
# 724      725  2012-12-25       1   1    12        1        2           0
# 725      726  2012-12-26       1   1    12        0        3           1
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 721           1  0.265833  0.236113  0.441250   0.407346     205        1544
# ...

# %%
data.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
# isolating to or more rows []
data[data.index.isin(range(1,20))]
# Out:
#     instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 1         2  2011-01-02       1   0     1        0        0           0
# 2         3  2011-01-03       1   0     1        0        1           1
# 3         4  2011-01-04       1   0     1        0        2           1
# 4         5  2011-01-05       1   0     1        0        3           1
# 5         6  2011-01-06       1   0     1        0        4           1
# 6         7  2011-01-07       1   0     1        0        5           1
# 7         8  2011-01-08       1   0     1        0        6           0
# 8         9  2011-01-09       1   0     1        0        0           0
# 9        10  2011-01-10       1   0     1        0        1           1
# 10       11  2011-01-11       1   0     1        0        2           1
# 11       12  2011-01-12       1   0     1        0        3           1
# 12       13  2011-01-13       1   0     1        0        4           1
# ...

# %%
data.loc[50]
# Out:
# instant               51
# dteday        2011-02-20
# season                 1
# yr                     0
# mnth                   2
# holiday                0
# weekday                0
# workingday             0
# weathersit             1
# temp            0.285217
# atemp            0.27733
# hum             0.407826
# windspeed       0.223235
# casual               639
# registered          1173
# cnt                 1812
# Name: 50, dtype: object

# %%
data.iloc[20:50]
# Out:
#     instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 20       21  2011-01-21       1   0     1        0        5           1
# 21       22  2011-01-22       1   0     1        0        6           0
# 22       23  2011-01-23       1   0     1        0        0           0
# 23       24  2011-01-24       1   0     1        0        1           1
# 24       25  2011-01-25       1   0     1        0        2           1
# 25       26  2011-01-26       1   0     1        0        3           1
# 26       27  2011-01-27       1   0     1        0        4           1
# 27       28  2011-01-28       1   0     1        0        5           1
# 28       29  2011-01-29       1   0     1        0        6           0
# 29       30  2011-01-30       1   0     1        0        0           0
# 30       31  2011-01-31       1   0     1        0        1           1
# 31       32  2011-02-01       1   0     2        0        2           1
# ...

# %%
data.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
# Data visualzation
# matplotlib and seaborn

# %%
sns.barplot(x='workingday', y = 'holiday', data=data)
# Out:
# <Axes: xlabel='workingday', ylabel='holiday'>

# %%
sns.lineplot(x="weathersit", y="windspeed", data=data)
# Out:
# <Axes: xlabel='weathersit', ylabel='windspeed'>

# %%
#matplotlib histograms plot
y =['mnth', 'holiday', 'weekday']
plt.hist(y)
plt.show()

# %%
#matplotlip pie charts
labels = ['casual', 'registered', 'cnt']
sizes = [40,45,15]

# ploting the pie chort
plt.pie(sizes, labels=labels, autopct='%1.1f%%',startangle=90)
plt.title('Ple Chart Example')
plt.show()

# %%
data.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
# matplotlib area plot
# Data
x = ['instant']
y1, y2 = ['weathersit'],['holiday']

#Area chart
plt.fill_between(x, y1, y2, color='skyblue', alpha=0.4, label='area 1-2')
plt.plot(x, y1, label='line 1', marker='o')
plt.plot(x, y2, label='line 2', marker='o')
plt.xlabel('x-axis'), plt.ylabel('y-axis'), plt.title('Area chart Example')
plt.legend()
plt.show()

# %%
sns.lineplot(data=data,x='workingday',y='windspeed')
# Out:
# <Axes: xlabel='workingday', ylabel='windspeed'>

# %%
data.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
import seaborn
# boxplot seaborn
seaborn.boxplot(x="mnth", y="atemp", data = data)
# Out:
# <Axes: xlabel='mnth', ylabel='atemp'>

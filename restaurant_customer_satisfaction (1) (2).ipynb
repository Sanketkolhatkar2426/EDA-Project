# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # New Section

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/restaurant_customer_satisfaction (1).csv')

# %%
df.head(40)
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35    Male   83380         Weekly     27.829142
# 1         655   19    Male   43623         Rarely    115.408622
# 2         656   41  Female   83737         Weekly    106.693771
# 3         657   43    Male   96768         Rarely     43.508508
# 4         658   55  Female   67937        Monthly    148.084627
# 5         659   42  Female   28860        Monthly    111.064696
# 6         660   20  Female  131104         Weekly    120.236707
# 7         661   51  Female  137882         Weekly    160.979098
# 8         662   27    Male  149638         Weekly     56.558632
# 9         663   32  Female  136145         Weekly     65.753455
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
# ...

# %%
df.tail(10)
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 1490        2144   20    Male  106717         Rarely    105.323720
# 1491        2145   47    Male   90569         Weekly    101.312053
# 1492        2146   20    Male   41041         Rarely     59.403047
# 1493        2147   62    Male  135684         Weekly    128.943101
# 1494        2148   25  Female  142332         Weekly    128.626784
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 1490           Indian   Breakfast          5         Casual  Takeaway
# 1491           Indian       Lunch          9         Casual  Takeaway
# ...

# %%
df.isna().sum()
# Out:
# CustomerID              0
# Age                     0
# Gender                  0
# Income                  0
# VisitFrequency          0
# AverageSpend            0
# PreferredCuisine        0
# TimeOfVisit             0
# GroupSize               0
# DiningOccasion          0
# MealType                0
# OnlineReservation       0
# DeliveryOrder           0
# LoyaltyProgramMember    0
# WaitTime                0
# ServiceRating           0
# FoodRating              0
# AmbianceRating          0
# HighSatisfaction        0
# dtype: int64

# %%
df.isnull().any()
# Out:
# CustomerID              False
# Age                     False
# Gender                  False
# Income                  False
# VisitFrequency          False
# AverageSpend            False
# PreferredCuisine        False
# TimeOfVisit             False
# GroupSize               False
# DiningOccasion          False
# MealType                False
# OnlineReservation       False
# DeliveryOrder           False
# LoyaltyProgramMember    False
# WaitTime                False
# ServiceRating           False
# FoodRating              False
# AmbianceRating          False
# HighSatisfaction        False
# dtype: bool

# %%
df.shape
# Out:
# (1500, 19)

# %%
df['Income'].sum()
# Out:
# 128882835

# %%
df['Gender']
# Out:
# 0         Male
# 1         Male
# 2       Female
# 3         Male
# 4       Female
#          ...
# 1495      Male
# 1496    Female
# 1497      Male
# 1498      Male
# 1499      Male
# Name: Gender, Length: 1500, dtype: object

# %%
df['Age'].head(20)>= 30
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7      True
# 8     False
# 9      True
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# Name: Age, dtype: bool

# %%
df[['CustomerID','Age','Gender']].head(10)
# Out:
#    CustomerID  Age  Gender
# 0         654   35    Male
# 1         655   19    Male
# 2         656   41  Female
# 3         657   43    Male
# 4         658   55  Female
# 5         659   42  Female
# 6         660   20  Female
# 7         661   51  Female
# 8         662   27    Male
# 9         663   32  Female

# %%
# isolating to or more rows []
df[df.index.isin(range(1,10))]
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 1         655   19    Male   43623         Rarely    115.408622
# 2         656   41  Female   83737         Weekly    106.693771
# 3         657   43    Male   96768         Rarely     43.508508
# 4         658   55  Female   67937        Monthly    148.084627
# 5         659   42  Female   28860        Monthly    111.064696
# 6         660   20  Female  131104         Weekly    120.236707
# 7         661   51  Female  137882         Weekly    160.979098
# 8         662   27    Male  149638         Weekly     56.558632
# 9         663   32  Female  136145         Weekly     65.753455
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 1         American      Dinner          1         Casual   Dine-in
# 2         American      Dinner          6    Celebration   Dine-in
# 3           Indian       Lunch          1    Celebration   Dine-in
# ...

# %%
df.describe()
# Out:
#         CustomerID          Age         Income  AverageSpend    GroupSize  \
# count  1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean   1403.500000    43.832000   85921.890000    105.659004     5.035333
# std     433.157015    14.967157   38183.051749     52.381849     2.558864
# min     654.000000    18.000000   20012.000000     10.306127     1.000000
# 25%    1028.750000    31.750000   52444.000000     62.287907     3.000000
# 50%    1403.500000    44.000000   85811.000000    104.626408     5.000000
# 75%    1778.250000    57.000000  119159.250000    148.649330     7.000000
# max    2153.000000    69.000000  149875.000000    199.973527     9.000000
#
#        OnlineReservation  DeliveryOrder  LoyaltyProgramMember     WaitTime  \
# count        1500.000000    1500.000000           1500.000000  1500.000000
# mean            0.296667       0.405333              0.480000    30.163550
# std             0.456941       0.491120              0.499766    17.214184
# ...

# %%
df.loc[50]
# Out:
# CustomerID                      704
# Age                              48
# Gender                       Female
# Income                       106670
# VisitFrequency               Weekly
# AverageSpend             196.461488
# PreferredCuisine            Italian
# TimeOfVisit               Breakfast
# GroupSize                         2
# DiningOccasion          Celebration
# MealType                   Takeaway
# OnlineReservation                 1
# DeliveryOrder                     1
# LoyaltyProgramMember              0
# WaitTime                  52.068878
# ServiceRating                     1
# FoodRating                        1
# AmbianceRating                    4
# HighSatisfaction                  0
# Name: 50, dtype: object

# %%
df.iloc[20:30]
# Out:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 20         674   27  Female   41450         Weekly     14.677697
# 21         675   40  Female   85259        Monthly     61.456659
# 22         676   20  Female  116507         Weekly    169.657810
# 23         677   51    Male   40666         Weekly     54.668755
# 24         678   21    Male   62296         Weekly    161.180604
# 25         679   40  Female   38099         Weekly    118.814236
# 26         680   51    Male  105609         Rarely     12.690321
# 27         681   68    Male   82470         Weekly    146.452729
# 28         682   49  Female   49402         Weekly     92.146409
# 29         683   59    Male   72461         Rarely    153.401540
#
#    PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 20          Chinese      Dinner          5    Celebration   Dine-in
# 21           Indian      Dinner          9       Business   Dine-in
# ...

# %%
A=df['Age'].value_counts()
print(A)
print("------------------------------------------------------")
GS=df['FoodRating'].value_counts()
print(GS)
print("------------------------------------------------------")
df['ServiceRating'].value_counts()
# Out:
# Age
# 59    37
# 42    37
# 37    36
# 23    35
# 36    35
# 47    34
# 46    34
# 19    34
# 54    34
# 40    33
# 21    33
# 32    33
# 56    33
# 65    32
# 52    32
# 39    32
# 67    32
# 62    31
# 60    31
# 57    31
# 35    31
# 18    31
# 25    30
# 61    30
# 31    30
# 44    30
# 69    29
# 53    29
# 64    29
# 38    28
# 58    28
# 66    27
# 33    27
# 50    27
# 41    26
# 49    26
# 51    26
# 28    26
# 26    25
# 63    25
# 68    25
# 55    24
# 22    24
# 45    24
# 43    23
# 34    23
# 20    23
# 24    23
# 30    23
# 48    21
# 27    20
# 29    18
# Name: count, dtype: int64
# ------------------------------------------------------
# FoodRating
# 3    315
# 1    313
# 4    300
# 5    298
# 2    274
# Name: count, dtype: int64
# ------------------------------------------------------
# ServiceRating
# 5    322
# 3    302
# 4    295
# 1    292
# 2    289
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Income', 'VisitFrequency',
#        'AverageSpend', 'PreferredCuisine', 'TimeOfVisit', 'GroupSize',
#        'DiningOccasion', 'MealType', 'OnlineReservation', 'DeliveryOrder',
#        'LoyaltyProgramMember', 'WaitTime', 'ServiceRating', 'FoodRating',
#        'AmbianceRating', 'HighSatisfaction'],
#       dtype='object')

# %%
# Data visualzation
# matplotlib and seaborn

# %% [markdown]
# DATA VISUALISATION WITH SEABORN

# %%
df.plot.bar(x='CustomerID',y='Age')
# Out:
# <Axes: xlabel='CustomerID'>

# %%
#matplotlib histograms plot
y =['VisitFrequency', 'PreferredCuisine', 'OnlineReservation']
plt.hist(y)
plt.show()

# %%
#countplot seaborn
sns.countplot(x ='Gender',data= df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#lineplot seaborn

sns.lineplot(data=df,x='PreferredCuisine',y='GroupSize')
plt.show()

# %%
#violinplot seaborn
import seaborn
seaborn.violinplot(x ='MealType', y ='OnlineReservation', data = df)
# Out:
# <Axes: xlabel='MealType', ylabel='OnlineReservation'>

# %%
#boxplot seaborn
seaborn.boxplot(x="DiningOccasion", y="GroupSize", data = df)
# Out:
# <Axes: xlabel='DiningOccasion', ylabel='GroupSize'>

# %%
seaborn.stripplot(x="FoodRating", y="WaitTime", data=df)
# Out:
# <Axes: xlabel='FoodRating', ylabel='WaitTime'>

# %%
import seaborn
df = seaborn.scatterplot(x="PreferredCuisine", y="GroupSize", data=df)
plt.show()

# %%
df = np.random.randn(100)
set = pd.Series(df,name="DeliveryOrder")
plot = sns.distplot(set,kde=True)
plt.show()
# Out:
# <ipython-input-53-2537216d4d80>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   plot = sns.distplot(set,kde=True)

# %%
#pairplot seaborn
sns.pairplot(df, hue = 'TimeOfVisit' )
# Out:
# Output hidden; open in https://colab.research.google.com to view.
